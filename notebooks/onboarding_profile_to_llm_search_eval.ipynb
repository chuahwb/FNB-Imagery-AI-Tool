# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/chuahwb/FNB-Imagery-AI-Tool.git
# Out:
# Cloning into 'FNB-Imagery-AI-Tool'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 13 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 6.17 KiB | 6.17 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
